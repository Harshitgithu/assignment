# %% [markdown]
# ## Question-1 :Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.

# %%
The Pearson correlation coefficient (r) is a measure of the linear relationship between two variables. It ranges from -1 to 1, where:

=
1
r=1 indicates a perfect positive linear relationship,
=
−
1
r=−1 indicates a perfect negative linear relationship, and
=
0
r=0 indicates no linear relationship.

 
 
After performing the calculations, let's say you find =
0.96
r=0.96.

Interpretation:=
0.96
r=0.96 is close to 1, indicating a very strong positive linear relationship between the amount of time students spend studying and their final exam scores.
As the time spent studying increases, the final exam scores tend to increase, and vice versa.
This suggests a highly positive correlation between study time and exam performance.
Remember that correlation does not imply causation, and other factors may influence the relationship.

# %% [markdown]
# ## Question-2 :Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

# %%
Spearman's rank correlation coefficient (
�
ρ) is a non-parametric measure of the strength and direction of the monotonic relationship between two variables. Unlike Pearson correlation, Spearman's correlation does not assume a linear relationship; it assesses whether there is a consistent monotonic relationship between the variables.

The formula for Spearman's rank correlation coefficient is as follows:

�
=
1
−
6
∑
�
�
2
�
(
�
2
−
1
)
ρ=1− 
n(n 
2
 −1)
6∑d 
i
2
​
 
​
 

where:

�
�
d 
i
​
  is the difference between the ranks of corresponding pairs of observations,
�
n is the number of observations.
Here's an example using hypothetical data on the amount of sleep individuals get each night (
�
X) and their overall job satisfaction level on a scale of 1 to 10 (
�
Y):

�
:
[
7
,
6
,
8
,
5
,
7
]
X:[7,6,8,5,7]
�
:
[
8
,
5
,
9
,
4
,
7
]
Y:[8,5,9,4,7]

Rank the data for each variable:
Rank of 
�
:
[
3
,
2
,
4
,
1
,
3
]
Rank of X:[3,2,4,1,3]
Rank of 
�
:
[
4
,
2
,
5
,
1
,
3
]
Rank of Y:[4,2,5,1,3]

Calculate the differences between ranks for each pair:
�
�
:
[
1
,
0
,
−
1
,
0
,
0
]
d 
i
​
 :[1,0,−1,0,0]

Plug the differences into the formula:
�
=
1
−
6
(
1
2
+
0
2
+
(
−
1
)
2
+
0
2
+
0
2
)
5
(
5
2
−
1
)
ρ=1− 
5(5 
2
 −1)
6(1 
2
 +0 
2
 +(−1) 
2
 +0 
2
 +0 
2
 )
​
 

After calculating, let's say you find 
�
=
0.2
ρ=0.2.

Interpretation:

�
=
0.2
ρ=0.2 indicates a weak positive monotonic relationship between the amount of sleep individuals get each night and their overall job satisfaction level.
As the amount of sleep increases, there is a tendency for job satisfaction to increase, but the relationship is not very strong.
The positive value of 
�
ρ indicates a positive monotonic trend, but the strength of the relationship is modest.
It's important to note that Spearman's rank correlation is sensitive to the relative order of ranks and is particularly useful when dealing with ordinal or non-normally distributed data.

# %% [markdown]
# ## Question-3 Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

# %%
Sure, let's assume you have the following hypothetical data for the number of hours of exercise per week (
�
X) and the body mass index (BMI) (
�
Y) for 50 participants:

�
:
[
3
,
5
,
2
,
6
,
4
,
…
]
X:[3,5,2,6,4,…]
�
:
[
25
,
30
,
22
,
28
,
27
,
…
]
Y:[25,30,22,28,27,…]

Now, let's calculate both the Pearson correlation coefficient (
�
r) and Spearman's rank correlation coefficient (
�
ρ).

Pearson Correlation Coefficient (
�
r):
The formula for Pearson correlation coefficient is:

�
=
∑
(
�
�
−
�
ˉ
)
(
�
�
−
�
ˉ
)
∑
(
�
�
−
�
ˉ
)
2
∑
(
�
�
−
�
ˉ
)
2
r= 
∑(X 
i
​
 − 
X
ˉ
 ) 
2
 ∑(Y 
i
​
 − 
Y
ˉ
 ) 
2
 
​
 
∑(X 
i
​
 − 
X
ˉ
 )(Y 
i
​
 − 
Y
ˉ
 )
​
 

where 
�
ˉ
X
ˉ
  and 
�
ˉ
Y
ˉ
  are the means of 
�
X and 
�
Y, respectively.

After calculating 
�
r, let's say you find 
�
=
0.72
r=0.72.

Spearman's Rank Correlation Coefficient (
�
ρ):
The steps for calculating Spearman's rank correlation coefficient are as follows:

Rank the data for each variable.
Calculate the differences between ranks for each pair.
Plug the differences into the formula:
�
=
1
−
6
∑
�
�
2
�
(
�
2
−
1
)
ρ=1− 
n(n 
2
 −1)
6∑d 
i
2
​
 
​
 

where 
�
�
d 
i
​
  is the difference between the ranks of corresponding pairs of observations and 
�
n is the number of observations.

After calculating 
�
ρ, let's say you find 
�
=
0.68
ρ=0.68.

Comparison:

Both coefficients (
�
r and 
�
ρ) provide measures of the strength and direction of the relationship between the number of hours of exercise per week and BMI.
�
=
0.72
r=0.72 indicates a strong positive linear relationship.
�
=
0.68
ρ=0.68 indicates a strong positive monotonic relationship.
While 
�
r measures linear relationships, 
�
ρ assesses monotonic relationships. In this case, the values are relatively close, suggesting that both linear and monotonic aspects of the relationship are strong. However, the choice between them may depend on the nature of the data and the assumptions of the relationship. If the relationship appears to be more linear, 
�
r might be more appropriate; if it's more monotonic, 
�
ρ might be preferred.

# %% [markdown]
# ## Question-4:A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between these two variables.

# %% [markdown]
# ## Question-6 :A company is interested in examining the relationship between the number of sales calls made per day and the number of sales made per week. The company collected data on both variables from a sample of 30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.
